# %%
# %pip install markitdown[all]
# Out:
# Requirement already satisfied: markitdown[all] in /usr/local/python/3.12.1/lib/python3.12/site-packages (0.1.2)
# Requirement already satisfied: beautifulsoup4 in /home/codespace/.local/lib/python3.12/site-packages (from markitdown[all]) (4.13.3)
# Requirement already satisfied: charset-normalizer in /home/codespace/.local/lib/python3.12/site-packages (from markitdown[all]) (3.4.1)
# Requirement already satisfied: defusedxml in /home/codespace/.local/lib/python3.12/site-packages (from markitdown[all]) (0.7.1)
# Requirement already satisfied: magika~=0.6.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from markitdown[all]) (0.6.2)
# Requirement already satisfied: markdownify in /usr/local/python/3.12.1/lib/python3.12/site-packages (from markitdown[all]) (1.1.0)
# Requirement already satisfied: requests in /home/codespace/.local/lib/python3.12/site-packages (from markitdown[all]) (2.32.3)
# Collecting azure-ai-documentintelligence (from markitdown[all])
#   Downloading azure_ai_documentintelligence-1.0.2-py3-none-any.whl.metadata (53 kB)
# Collecting azure-identity (from markitdown[all])
#   Downloading azure_identity-1.23.0-py3-none-any.whl.metadata (81 kB)
# Collecting lxml (from markitdown[all])
#   Downloading lxml-5.4.0-cp312-cp312-manylinux_2_28_x86_64.whl.metadata (3.5 kB)
# Collecting mammoth (from markitdown[all])
#   Downloading mammoth-1.9.1-py2.py3-none-any.whl.metadata (24 kB)
# Collecting olefile (from markitdown[all])
#   Downloading olefile-0.47-py2.py3-none-any.whl.metadata (9.7 kB)
# Collecting openpyxl (from markitdown[all])
#   Downloading openpyxl-3.1.5-py2.py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: pandas in /home/codespace/.local/lib/python3.12/site-packages (from markitdown[all]) (2.2.3)
# Collecting pdfminer-six (from markitdown[all])
#   Downloading pdfminer_six-20250506-py3-none-any.whl.metadata (4.2 kB)
# Collecting pydub (from markitdown[all])
#   Downloading pydub-0.25.1-py2.py3-none-any.whl.metadata (1.4 kB)
# Collecting python-pptx (from markitdown[all])
#   Downloading python_pptx-1.0.2-py3-none-any.whl.metadata (2.5 kB)
# Collecting speechrecognition (from markitdown[all])
#   Downloading speechrecognition-3.14.3-py3-none-any.whl.metadata (30 kB)
# Collecting xlrd (from markitdown[all])
#   Downloading xlrd-2.0.2-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting youtube-transcript-api~=1.0.0 (from markitdown[all])
#   Downloading youtube_transcript_api-1.0.3-py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: click>=8.1.7 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from magika~=0.6.1->markitdown[all]) (8.2.1)
# Requirement already satisfied: onnxruntime>=1.17.0 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from magika~=0.6.1->markitdown[all]) (1.22.0)
# Requirement already satisfied: numpy>=1.26 in /home/codespace/.local/lib/python3.12/site-packages (from magika~=0.6.1->markitdown[all]) (2.2.4)
# Requirement already satisfied: python-dotenv>=1.0.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from magika~=0.6.1->markitdown[all]) (1.1.0)
# Collecting isodate>=0.6.1 (from azure-ai-documentintelligence->markitdown[all])
#   Downloading isodate-0.7.2-py3-none-any.whl.metadata (11 kB)
# Collecting azure-core>=1.30.0 (from azure-ai-documentintelligence->markitdown[all])
#   Downloading azure_core-1.34.0-py3-none-any.whl.metadata (42 kB)
# Requirement already satisfied: typing-extensions>=4.6.0 in /home/codespace/.local/lib/python3.12/site-packages (from azure-ai-documentintelligence->markitdown[all]) (4.12.2)
# Collecting cryptography>=2.5 (from azure-identity->markitdown[all])
#   Downloading cryptography-45.0.4-cp311-abi3-manylinux_2_28_x86_64.whl.metadata (5.7 kB)
# Collecting msal>=1.30.0 (from azure-identity->markitdown[all])
#   Downloading msal-1.32.3-py3-none-any.whl.metadata (11 kB)
# Collecting msal-extensions>=1.2.0 (from azure-identity->markitdown[all])
#   Downloading msal_extensions-1.3.1-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: soupsieve>1.2 in /home/codespace/.local/lib/python3.12/site-packages (from beautifulsoup4->markitdown[all]) (2.6)
# Collecting cobble<0.2,>=0.1.3 (from mammoth->markitdown[all])
#   Downloading cobble-0.1.4-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: six<2,>=1.15 in /home/codespace/.local/lib/python3.12/site-packages (from markdownify->markitdown[all]) (1.17.0)
# Collecting et-xmlfile (from openpyxl->markitdown[all])
#   Downloading et_xmlfile-2.0.0-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->markitdown[all]) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->markitdown[all]) (2025.1)
# Requirement already satisfied: tzdata>=2022.7 in /home/codespace/.local/lib/python3.12/site-packages (from pandas->markitdown[all]) (2025.1)
# Requirement already satisfied: Pillow>=3.3.2 in /home/codespace/.local/lib/python3.12/site-packages (from python-pptx->markitdown[all]) (11.1.0)
# Collecting XlsxWriter>=0.5.7 (from python-pptx->markitdown[all])
#   Downloading XlsxWriter-3.2.3-py3-none-any.whl.metadata (2.7 kB)
# Requirement already satisfied: idna<4,>=2.5 in /home/codespace/.local/lib/python3.12/site-packages (from requests->markitdown[all]) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/codespace/.local/lib/python3.12/site-packages (from requests->markitdown[all]) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /home/codespace/.local/lib/python3.12/site-packages (from requests->markitdown[all]) (2025.1.31)
# Requirement already satisfied: cffi>=1.14 in /home/codespace/.local/lib/python3.12/site-packages (from cryptography>=2.5->azure-identity->markitdown[all]) (1.17.1)
# Collecting PyJWT<3,>=1.0.0 (from PyJWT[crypto]<3,>=1.0.0->msal>=1.30.0->azure-identity->markitdown[all])
#   Downloading PyJWT-2.10.1-py3-none-any.whl.metadata (4.0 kB)
# Requirement already satisfied: coloredlogs in /usr/local/python/3.12.1/lib/python3.12/site-packages (from onnxruntime>=1.17.0->magika~=0.6.1->markitdown[all]) (15.0.1)
# Requirement already satisfied: flatbuffers in /usr/local/python/3.12.1/lib/python3.12/site-packages (from onnxruntime>=1.17.0->magika~=0.6.1->markitdown[all]) (25.2.10)
# Requirement already satisfied: packaging in /home/codespace/.local/lib/python3.12/site-packages (from onnxruntime>=1.17.0->magika~=0.6.1->markitdown[all]) (24.2)
# Requirement already satisfied: protobuf in /usr/local/python/3.12.1/lib/python3.12/site-packages (from onnxruntime>=1.17.0->magika~=0.6.1->markitdown[all]) (6.31.1)
# Requirement already satisfied: sympy in /home/codespace/.local/lib/python3.12/site-packages (from onnxruntime>=1.17.0->magika~=0.6.1->markitdown[all]) (1.13.1)
# Requirement already satisfied: pycparser in /home/codespace/.local/lib/python3.12/site-packages (from cffi>=1.14->cryptography>=2.5->azure-identity->markitdown[all]) (2.22)
# Requirement already satisfied: humanfriendly>=9.1 in /usr/local/python/3.12.1/lib/python3.12/site-packages (from coloredlogs->onnxruntime>=1.17.0->magika~=0.6.1->markitdown[all]) (10.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /home/codespace/.local/lib/python3.12/site-packages (from sympy->onnxruntime>=1.17.0->magika~=0.6.1->markitdown[all]) (1.3.0)
# Downloading youtube_transcript_api-1.0.3-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 68.9 MB/s eta 0:00:00
# Downloading azure_ai_documentintelligence-1.0.2-py3-none-any.whl (106 kB)
# Downloading azure_identity-1.23.0-py3-none-any.whl (186 kB)
# Downloading lxml-5.4.0-cp312-cp312-manylinux_2_28_x86_64.whl (5.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.0/5.0 MB 84.1 MB/s eta 0:00:00
# Downloading mammoth-1.9.1-py2.py3-none-any.whl (52 kB)
# Downloading olefile-0.47-py2.py3-none-any.whl (114 kB)
# Downloading openpyxl-3.1.5-py2.py3-none-any.whl (250 kB)
# Downloading pdfminer_six-20250506-py3-none-any.whl (5.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 85.2 MB/s eta 0:00:00
# Downloading pydub-0.25.1-py2.py3-none-any.whl (32 kB)
# Downloading python_pptx-1.0.2-py3-none-any.whl (472 kB)
# Downloading speechrecognition-3.14.3-py3-none-any.whl (32.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 32.9/32.9 MB 85.8 MB/s eta 0:00:00:00:01
# Downloading xlrd-2.0.2-py2.py3-none-any.whl (96 kB)
# Downloading azure_core-1.34.0-py3-none-any.whl (207 kB)
# Downloading cobble-0.1.4-py3-none-any.whl (4.0 kB)
# Downloading cryptography-45.0.4-cp311-abi3-manylinux_2_28_x86_64.whl (4.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.5/4.5 MB 82.0 MB/s eta 0:00:00
# Downloading isodate-0.7.2-py3-none-any.whl (22 kB)
# Downloading msal-1.32.3-py3-none-any.whl (115 kB)
# Downloading msal_extensions-1.3.1-py3-none-any.whl (20 kB)
# Downloading XlsxWriter-3.2.3-py3-none-any.whl (169 kB)
# Downloading et_xmlfile-2.0.0-py3-none-any.whl (18 kB)
# Downloading PyJWT-2.10.1-py3-none-any.whl (22 kB)
# Installing collected packages: pydub, XlsxWriter, xlrd, speechrecognition, PyJWT, olefile, lxml, isodate, et-xmlfile, cobble, youtube-transcript-api, python-pptx, openpyxl, mammoth, cryptography, azure-core, pdfminer-six, azure-ai-documentintelligence, msal, msal-extensions, azure-identity
# Successfully installed PyJWT-2.10.1 XlsxWriter-3.2.3 azure-ai-documentintelligence-1.0.2 azure-core-1.34.0 azure-identity-1.23.0 cobble-0.1.4 cryptography-45.0.4 et-xmlfile-2.0.0 isodate-0.7.2 lxml-5.4.0 mammoth-1.9.1 msal-1.32.3 msal-extensions-1.3.1 olefile-0.47 openpyxl-3.1.5 pdfminer-six-20250506 pydub-0.25.1 python-pptx-1.0.2 speechrecognition-3.14.3 xlrd-2.0.2 youtube-transcript-api-1.0.3
#
# [notice] A new release of pip is available: 25.0.1 -> 25.1.1
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from markitdown import MarkItDown
# Out:
# /usr/local/python/3.12.1/lib/python3.12/site-packages/pydub/utils.py:170: RuntimeWarning: Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work
#   warn("Couldn't find ffmpeg or avconv - defaulting to ffmpeg, but may not work", RuntimeWarning)

# %%
md = MarkItDown(enable_plugins=False) # Set to True to enable plugins
result = md.convert("Basic time-series analysis in Pandas.pptx")
print(result.text_content)
# Out:
# <!-- Slide number: 1 -->
# # Basic timeseries analysis in Pandas
# Stelios Christodoulou
# PyData London
# June 2025
#
# ### Notes:
#
# <!-- Slide number: 2 -->
#
# # Basic timeseries analysis in Pandas
# autocorrelation_plot()
# .diff()
# .autocorr()
#
# lag_plot()
# Test for randomness and periodicity
# Focus on a particular lag identified from the autocorrelation plot
# Difference function: highlighting discontinuities, removing “dc components”
# Calculate the numerical value for autocorrelation at the particular lag
#
# ### Notes:
#
# <!-- Slide number: 3 -->
#
# # Autocorrelation Plot
#
# ![](GoogleShape492p53.jpg)
#
# ![](GoogleShape491p53.jpg)
# Not random
# Trend dominates over periodicity
#
# ### Notes:
#
# <!-- Slide number: 4 -->
#
# # Lag 1 and autocorr
#
# ![](GoogleShape502p54.jpg)
#
# ![](GoogleShape503p54.jpg)
# Not random confirmed
#
# ### Notes:
#
# <!-- Slide number: 5 -->
#
# # For the computationally minded
#
# ![](GoogleShape508p55.jpg)
# Why aren’t the numbers identical?
# Which one is correct?
#
# ### Notes:
#
# <!-- Slide number: 6 -->
#
# # Diff and Lag
#
# ![](GoogleShape523p56.jpg)
#
# ![](GoogleShape524p56.jpg)
#
# ![](GoogleShape522p56.jpg)
#
# ![](GoogleShape525p56.jpg)
# Diff makes lag 1 random
#
# ### Notes:
#
# <!-- Slide number: 7 -->
#
# # Diff and Autocorrelation
#
# ![](GoogleShape535p57.jpg)
# Periodicity comes to the fore
#
# ### Notes:
#
# <!-- Slide number: 8 -->
#
# ![](GoogleShape547p58.jpg)
# # Lag for periodicity
#
# ![](GoogleShape546p58.jpg)
# Diff and lag 12  quite correlated
# Diff and lag 6 weakly correlated
#
# ### Notes:
#
# <!-- Slide number: 9 -->
#
# # Thank you
#
# Bibliography
# Pandas documentation
# NIST/SEMATECH e-Handbook of Statistical Methods
# Random Processes chapter in Communication Systems (Haykin)
# https://github.com/stelios-c/sig_proc/
# Released under the GPL 3.0 Licence.
# Inspired from a Linked In post by Kunpeng (KP) Liao.
#
# ### Notes:
